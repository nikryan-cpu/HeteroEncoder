# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("dataset.csv")

# %%
dataset['Energy'].plot(kind='hist', bins=200, xlim=(-20,0))
# Out:
# <Axes: ylabel='Frequency'>

# %%
dataset[dataset['Energy'].between(-20, -9.7)].size
# Out:
# 170208

# %%
dataset.size
# Out:
# 503484
